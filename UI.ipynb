# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df=pd.read_csv("Data.csv")

# %%
df
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1244            0.051                         1.617                0.859
# 1245            0.059                         1.357                0.947
# 1246            0.071                         1.648                0.936
# 1247            0.076                         1.560                0.921
# 1248            0.047                         1.395                0.859
#
#       Time to Visually Complete [s]  \
# 0                             0.993
# ...

# %%
profile=ProfileReport(df,title="Data Profile Report",explorative=True)

# %%
profile.to_file("PandasReport.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 19.76it/s]

# %%
df1=df.copy()

# %%
df1
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1244            0.051                         1.617                0.859
# 1245            0.059                         1.357                0.947
# 1246            0.071                         1.648                0.936
# 1247            0.076                         1.560                0.921
# 1248            0.047                         1.395                0.859
#
#       Time to Visually Complete [s]  \
# 0                             0.993
# ...

# %%
df1.drop(["Elapsed Time from First to Last Round Trip Excluding Gaps [s]"],axis=1,inplace=True)

# %%
df1[df1['End to end response time [s]'].isna()]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 83                NaN                           NaN                  NaN
# 84                NaN                           NaN                  NaN
# 259             0.088                           NaN                  NaN
# 260             0.080                           NaN                  NaN
# 610             0.166                           NaN                  NaN
# 611             0.323                           NaN                  NaN
# 779             0.164                           NaN                  NaN
# 780             0.143                           NaN                  NaN
# 1005            0.547                           NaN                  NaN
# 1050            0.279                           NaN                  NaN
# 1136            0.242                           NaN                  NaN
#
#       Time to Visually Complete [s]
# 83                            0.695
# ...

# %%
df1.dropna(subset = ["End to end response time [s]"], inplace=True)

# %%
df1[df1['TTVC - TTLC [s]'].isna()]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 72                NaN                         2.768                  NaN
# 73                NaN                         1.673                  NaN
# 76                NaN                         2.595                0.031
# 79                NaN                         3.630                  NaN
# 81                NaN                         3.246                  NaN
# 82                NaN                         3.875                  NaN
# 86                NaN                         2.998                  NaN
# 87                NaN                         3.489                  NaN
# 88                NaN                         2.890                  NaN
# 89                NaN                         1.905                  NaN
# 90                NaN                         1.757                  NaN
# 91                NaN                         2.720                  NaN
# ...

# %%
df1.dropna(subset = ["TTVC - TTLC [s]","Client CPU Time [s]"], inplace=True, how="all")

# %%
df1[df1['TTVC - TTLC [s]'].isna()]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 76                NaN                         2.595                0.031
# 1119              NaN                         1.279                1.806
# 1120              NaN                         1.549                2.206
# 1121              NaN                         1.617                2.122
# 1122              NaN                         1.357                1.833
# 1125              NaN                         1.395                1.842
#
#       Time to Visually Complete [s]
# 76                            1.238
# 1119                          0.823
# 1120                          0.873
# 1121                          0.835
# 1122                          0.816
# 1125                          0.862

# %%
df1['TTVC - TTLC [s]'].fillna(value=df['TTVC - TTLC [s]'].mean(), inplace=True)

# %%
df1.dropna(subset = ["Client CPU Time [s]","Time to Visually Complete [s]"], inplace=True, how="all")

# %%
df1.isnull().sum()
# Out:
# TTVC - TTLC [s]                    0
# End to end response time [s]       0
# Client CPU Time [s]               62
# Time to Visually Complete [s]    121
# dtype: int64

# %%
df1[df1['Time to Visually Complete [s]'].isna()]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 112             0.285                         1.271                2.136
# 227             0.528                         2.846                2.666
# 485             0.266                         1.122                1.494
# 486             0.110                         1.050                1.378
# 635             0.176                         2.816                3.094
# ...               ...                           ...                  ...
# 1244            0.051                         1.617                0.859
# 1245            0.059                         1.357                0.947
# 1246            0.071                         1.648                0.936
# 1247            0.076                         1.560                0.921
# 1248            0.047                         1.395                0.859
#
#       Time to Visually Complete [s]
# 112                             NaN
# ...

# %%
df1.dropna(subset = ["Time to Visually Complete [s]","Client CPU Time [s]"], inplace=True)

# %%
df1.isnull().sum()
# Out:
# TTVC - TTLC [s]                  0
# End to end response time [s]     0
# Client CPU Time [s]              0
# Time to Visually Complete [s]    0
# dtype: int64

# %%
df2=df1.copy()
df3=df1.copy()

# %%
df1.count
# Out:
# <bound method DataFrame.count of       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1143            0.397                         1.997                0.978
# 1144            0.000                         1.477                0.906
# 1145            0.000                         1.370                0.989
# 1146            0.347                         2.033                1.190
# 1147            0.332                         2.152                1.165
#
#       Time to Visually Complete [s]
# ...

# %%
df1.to_excel("Data_Cleaned.xlsx")

# %%
#df1[['TTVC - TTLC [s]', 'End to end response time [s]','End to end response time [s]','Client CPU Time [s]','Time to Visually Complete [s]']] = StandardScaler().fit_transform(df1[['TTVC - TTLC [s]', 'End to end response time [s]','End to end response time [s]','Client CPU Time [s]','Time to Visually Complete [s]']])

# %%
#df1
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0            0.865945                      2.889057             2.130708
# 1            0.817883                      1.419965             1.739751
# 2            0.649668                      2.734692             1.842665
# 3            1.425860                      2.468063             1.794945
# 4            0.803465                      0.052614             1.838065
# ...               ...                           ...                  ...
# 1143         0.224325                     -0.305231            -0.926803
# 1144        -0.729695                     -0.761307            -0.968198
# 1145        -0.729695                     -0.855153            -0.920478
# 1146         0.104171                     -0.273656            -0.804916
# 1147         0.068125                     -0.169285            -0.819290
#
#       Time to Visually Complete [s]
# 0                         -0.622035
# ...

# %%
profile1=ProfileReport(df1,title="sandartization_report",explorative=True)
profile1.to_file("sand_PandasReport.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 55.45it/s]

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,15):
    kmean = KMeans(n_clusters=i , init='k-means++' , random_state=30)
    kmean.fit(df1)
    wcss.append(kmean.inertia_)

# %%
wcss
# Out:
# [7603.2221103592765,
#  5225.287492554628,
#  3747.7208417795764,
#  2839.7720615256585,
#  2289.875248983151,
#  1926.335681772706,
#  1739.7475237246333,
#  1582.3690886595991,
#  1445.1222382346482,
#  1316.9969504716955,
#  1205.7508359040692,
#  1124.8914218681457,
#  1059.5357869481613,
#  984.6003188469391]

# %%
plt.plot(range(1,15) , wcss)

# %%
kmean = KMeans(n_clusters=3,init = 'k-means++',random_state=30)

# %%
kmean.fit(df1)
# Out:
# KMeans(n_clusters=3, random_state=30)

# %%
df1['cluster number'] = kmean.fit_predict(df1)

# %%
df1
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1143            0.397                         1.997                0.978
# 1144            0.000                         1.477                0.906
# 1145            0.000                         1.370                0.989
# 1146            0.347                         2.033                1.190
# 1147            0.332                         2.152                1.165
#
#       Time to Visually Complete [s]  cluster number
# ...

# %%
df1[df1['cluster number'] ==0]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 76            0.31893                         2.595                0.031
# 80            0.32600                         2.649                0.189
# 99            0.48500                         2.949                0.595
# 101           0.54200                         0.672                1.053
# 102           0.49300                         1.281                2.086
# ...               ...                           ...                  ...
# 1143          0.39700                         1.997                0.978
# 1144          0.00000                         1.477                0.906
# 1145          0.00000                         1.370                0.989
# 1146          0.34700                         2.033                1.190
# 1147          0.33200                         2.152                1.165
#
#       Time to Visually Complete [s]  cluster number
# ...

# %%
df1[df1['cluster number'] ==1]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1087            0.000                         5.415                2.792
# 1088            0.000                         5.300                2.885
# 1104            0.000                         3.807                3.957
# 1107            0.000                         3.593                3.952
# 1108            0.000                         3.631                3.625
#
#       Time to Visually Complete [s]  cluster number
# ...

# %%
df1[df1['cluster number']==2]
# Out:
#      TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 483            0.075                         1.263                1.797
# 487            0.126                         1.059                1.458
# 606            0.191                         3.630                6.273
# 607            0.228                         2.649                5.953
# 608            0.221                         3.246                5.976
# 643            0.180                         1.844                2.965
# 645            0.246                         1.929                3.010
# 984            0.501                         1.747                1.767
# 985            0.498                         2.035                3.184
# 986            0.488                         2.080                3.246
# 987            0.510                         1.529                2.275
#
#      Time to Visually Complete [s]  cluster number
# 483                          8.429               2
# ...

# %%
df1[df1['cluster number']==3]
# Out:
# Empty DataFrame
# Columns: [TTVC - TTLC [s], End to end response time [s], Client CPU Time [s], Time to Visually Complete [s], cluster number]
# Index: []

# %%
df1.to_excel("Final_Cluster.xlsx")

# %%
kmean.predict([[40.075,1.263,1.797,8.429]])
# Out:
# array([2])

# %%
import pickle
pickle_out = open("kmean.pkl","wb")
pickle.dump(kmean,pickle_out)
pickle_out.close()

# %%
from  sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=1, min_samples=4)
dbscan.fit(df2)
# Out:
# DBSCAN(eps=1, min_samples=4)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df2['dbscan_cluster_name'] = dbscan.labels_

# %%
df2
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1143            0.397                         1.997                0.978
# 1144            0.000                         1.477                0.906
# 1145            0.000                         1.370                0.989
# 1146            0.347                         2.033                1.190
# 1147            0.332                         2.152                1.165
#
#       Time to Visually Complete [s]  dbscan_cluster_name
# ...

# %%
#df2.drop(['dbscan_cluster_name'],axis=1,inplace=True)

# %%
df2.dbscan_cluster_name .unique()
# Out:
# array([ 0, -1], dtype=int64)

# %%
df2[df2['dbscan_cluster_name']==0]
# Out:
#       TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 0               0.664                         5.639                6.296
# 1               0.644                         3.964                5.616
# 2               0.574                         5.463                5.795
# 3               0.897                         5.159                5.712
# 4               0.638                         2.405                5.787
# ...               ...                           ...                  ...
# 1143            0.397                         1.997                0.978
# 1144            0.000                         1.477                0.906
# 1145            0.000                         1.370                0.989
# 1146            0.347                         2.033                1.190
# 1147            0.332                         2.152                1.165
#
#       Time to Visually Complete [s]  dbscan_cluster_name
# ...

# %%
df2[df2['dbscan_cluster_name']==-1]
# Out:
#      TTVC - TTLC [s]  End to end response time [s]  Client CPU Time [s]  \
# 21             2.106                         5.953                9.653
# 53             2.217                         2.011                6.249
# 55             3.088                         3.372                5.133
# 61             2.908                         4.967                9.013
# 62             4.111                         2.929               10.172
# 65             3.317                         3.989               10.564
# 71             2.076                         2.119                5.866
# 77             3.466                         4.278               12.938
# 207            0.460                         3.043                3.832
# 209            0.524                         3.800                3.777
# 211            0.478                         4.680                2.423
# 216            0.562                         2.331                3.833
# ...

# %%
df2.to_excel("Final_Cluster_DBSCAN.xlsx")

# %%
dbscan.fit_predict([[0.510,1.529,2.275,17.395]])
# Out:
# array([-1], dtype=int64)

# %%
import pickle
pickle_out = open("dbscan.pkl","wb")
pickle.dump(dbscan,pickle_out)
pickle_out.close()
